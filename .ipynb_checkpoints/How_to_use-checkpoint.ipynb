# %% [markdown]
# # grainanalyser
# > workflow to read grain-size distributions from the lab, with treating grain sizes as compositional data and therefore processing them using the Aitchison's log-ratio approach

# %% [markdown]
# ## Prerequisites
#
# * only works for one directory at a time
# * only works for csv files
# * only works for files in laserscannerformat

# %%
# %load_ext lab_black

# %%
from Functions import *

# %%
# install packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob as glob


import composition_stats as comp

## note that package is not applicable in pandas
## --> therefore convert dataframe columns to array (.values)

# %%
pd.set_option("display.max_rows", 15)  # none to view all rows

# %% [markdown]
# ### Data Wrangling

# %%
filepath = "Data\*.csv"
grainsizes = read_gs_to_df(filepath)


grainsizes_prep = cut_off_zeros(grainsizes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [21], line 2
#       1 filepath = "Data\*.csv"
# ----> 2 grainsizes = read_gs_to_df(filepath)
#       5 grainsizes_prep = cut_off_zeros(grainsizes)
#
# File D:\UNi\MASTER_FU\Master_Arbeit\grainalyzer\Functions.py:44, in read_gs_to_df(filepath)
#      42 import numpy as np
#      43 import pandas as pd
# ---> 44 import glob as glob
#      46 #################################################
#      47 ## step 1: DATA WRANGLING
#      48 grainsizes = pd.DataFrame()
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ### Convert Grainsize to Krumbein Phi Scale
#
# $$\phi = -\log_2 D/D_0\text{,} $$
#
# > relevant for later classification

# %%
grainsizes_prep["gs_phi"] = diameter_2_krumbein_phi(
    channelwidth=grainsizes_prep["Kanaldurchmesser_unten_um"], unit="um"
)

# %% [markdown]
# ***
#
# ### clr on Vol_% column
#
# > hier wird die clr mithilfe von composition.stats berechnet (alle aliquoten messungen
#
# > Zeros sind an den rändern abgeschnitten, sodasss nur noch die nullstellen innerhalb probleme machen
#
# > diese werden mit `multiplicative_replacement` ersetzt
#
# > closure: summe alle werte = 1

# %%
grainsizes_clr = gs_simplex_2_rplus(dataframe=grainsizes_prep, depth_colum="depth")

# %% [markdown]
# ### Summarize the subsamples into one mean curve!

# %%
grainsizes_summarize = mean_curves_clr(dataframe=grainsizes_clr, depth_colum="depth")
grainsizes_summarize

# %% [markdown]
# ### Save to csv

# %%
filepath = "grainsizes_summarize.csv"
grainsizes_summarize.to_csv(filepath, index=False)

# %% [markdown]
# **********
# ## Plotting
#
# > plotting all avg. curves in one plot (viridis)

# %%
from matplotlib.pyplot import cm

# %%
## convert back to % for sanity


n = len(pd.unique(grainsizes_summarize["depth"]))  ## number of curves here
color = cm.viridis(np.linspace(0, 1, n))
fig, ax = plt.subplots(1, 1, figsize=(15, 10))

for depth, c in zip(
    pd.unique(grainsizes_summarize["depth"]), color
):  # iterate over all depths and colors --> same lengths!
    plot_curve = grainsizes_summarize.loc[(grainsizes_summarize["depth"] == depth)]
    # depth = plot_curve["depth"].iloc[0]
    plt.plot(
        plot_curve["gs_phi"],
        comp.clr_inv(plot_curve["Vol_clr_mean"]) * 100,
        label=f"{depth}cm",
        color=c,
    )  # interim_ali["Vol_perc_clr"]
    # Add confidence bands
    # plt.fill_between(plot_curve["gs_phi"],
    #                  comp.clr_inv((plot_curve["Vol_clr_mean"]-plot_curve["Vol_clr_std"]))*100,
    #                  comp.clr_inv((plot_curve["Vol_clr_mean"]+plot_curve["Vol_clr_std"]))*100,
    #                  color=c, alpha=.1)
    plt.legend(loc="lower center", ncol=2, bbox_to_anchor=(1, 0.2))

plt.title("mean grain size and confidence bands\n no organik matter")
plt.xlabel("Grainsizes $\phi$")
plt.ylabel("Volume [%]")
plt.xlim(0, 16)
plt.show()

# %%
## convert back to % for sanity
desired_gs = [550,560,570,580,590,600,610, 630, 640, 650,670, 680,690,710, 720,740, 750,770, 780,790]


n = len(desired_gs) ## number of curves here
color = cm.viridis(np.linspace(0, 1, n)) 
fig, ax = plt.subplots(1,1, figsize=(15, 10))

for depth, c in zip(desired_gs, color): # iterate over all depths and colors --> same lengths!
    plot_curve = grainsizes_summarize.loc[(grainsizes_summarize['depth'] == depth)]
    age = plot_curve["median"].iloc[0]
    plt.plot(plot_curve["gs_phi"], comp.clr_inv(plot_curve["Vol_clr_mean"])*100, label = f"{depth}cm, age:{age}", color = c ) # interim_ali["Vol_perc_clr"]
    # Add confidence bands
    plt.fill_between(plot_curve["gs_phi"], 
                     comp.clr_inv((plot_curve["Vol_clr_mean"]-plot_curve["Vol_clr_std"]))*100, 
                     comp.clr_inv((plot_curve["Vol_clr_mean"]+plot_curve["Vol_clr_std"]))*100, 
                     color=c, alpha=.1)
    plt.legend()

plt.title('mean grain size and confidence bands\n no organik matter')
plt.xlabel('Grainsizes $\phi$')
plt.ylabel('Volume [%] (clr inverse)')
plt.xlim(0,16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\envs\rasterdata\lib\site-packages\pandas\core\indexes\base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File ~\miniconda3\envs\rasterdata\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\miniconda3\envs\rasterdata\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'median'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [15], line 11
#       9 for depth, c in zip(desired_gs, color): # iterate over all depths and colors --> same lengths!
#      10     plot_curve = grainsizes_summarize.loc[(grainsizes_summarize['depth'] == depth)]
# ---> 11     age = plot_curve["median"].iloc[0]
#      12     plt.plot(plot_curve["gs_phi"], comp.clr_inv(plot_curve["Vol_clr_mean"])*100, label = f"{depth}cm, age:{age}", color = c ) # interim_ali["Vol_perc_clr"]
#      13     # Add confidence bands
#
# File ~\miniconda3\envs\rasterdata\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File ~\miniconda3\envs\rasterdata\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
# -> 3802     raise KeyError(key) from err
#    3803 except TypeError:
#    3804     # If we have a listlike key, _check_indexing_error will raise
#    3805     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3806     #  the TypeError.
#    3807     self._check_indexing_error(key)
#
# KeyError: 'median'
